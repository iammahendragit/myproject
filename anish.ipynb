# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn
from sklearn import metrics

# %%
dataset = pd.read_csv('./FinalSetOfData.csv')
dataset
# Out:
#             Date  miniTemp  maxTemp  humidityAt3  humidityAt12  precipitation
# 0       1/1/2010      10.0     19.0        92.50         91.10            0.0
# 1       1/2/2010      10.5     22.7        77.70         95.70            0.0
# 2       1/3/2010      10.0     18.5        94.80         95.30            0.0
# 3       1/4/2010       8.5     18.5        89.60        100.00            0.0
# 4       1/5/2010       7.0     21.5        97.20        100.00            0.0
# ...          ...       ...      ...          ...           ...            ...
# 4371  12/27/2021      13.0     24.0        67.56         79.82            0.0
# 4372  12/28/2021      12.6     24.0        67.62         76.69            0.0
# 4373  12/29/2021      16.0     18.5        95.04         82.33            0.1
# 4374  12/30/2021      12.5     24.0        71.48         79.92            5.7
# 4375  12/31/2021      11.0     24.5        67.96         84.67            0.0
#
# [4376 rows x 6 columns]

# %%
def month(d):
    return d.split('/')[0]


dates = map(month, dataset['Date'])
dataset['Month'] = list(dates)

# %%
dataset
# Out:
#             Date  miniTemp  maxTemp  humidityAt3  humidityAt12  precipitation  \
# 0       1/1/2010      10.0     19.0        92.50         91.10            0.0
# 1       1/2/2010      10.5     22.7        77.70         95.70            0.0
# 2       1/3/2010      10.0     18.5        94.80         95.30            0.0
# 3       1/4/2010       8.5     18.5        89.60        100.00            0.0
# 4       1/5/2010       7.0     21.5        97.20        100.00            0.0
# ...          ...       ...      ...          ...           ...            ...
# 4371  12/27/2021      13.0     24.0        67.56         79.82            0.0
# 4372  12/28/2021      12.6     24.0        67.62         76.69            0.0
# 4373  12/29/2021      16.0     18.5        95.04         82.33            0.1
# 4374  12/30/2021      12.5     24.0        71.48         79.92            5.7
# 4375  12/31/2021      11.0     24.5        67.96         84.67            0.0
#
#      Month
# 0        1
# ...

# %%
dataset.plot(x='humidityAt3', y='precipitation', style='o')
plt.title('humidity vs precipitation')
plt.xlabel('Humidity at 3:00')
plt.ylabel('Precipitation')
plt.show()

# %%
dataset.plot(x='humidityAt12', y='precipitation', style='o')
plt.title('humidity vs precipitation')
plt.xlabel('Humidity at 12:00')
plt.ylabel('Precipitation')
plt.show()

# %%
dataset.plot(x='miniTemp', y='precipitation', style='o')
plt.title('minimum temperature  vs precipitation')
plt.xlabel('Minimum temperature ')
plt.ylabel('Precipitation')
plt.show()

# %%
dataset.plot(x='maxTemp', y='precipitation', style='o')
plt.title('maximum temperature  vs precipitation')
plt.xlabel('Maxmum temperature ')
plt.ylabel('Precipitation')
plt.show()

# %%
dataset.plot(x='Month', y='precipitation', style='o')
plt.title('Month vs precipitation')
plt.xlabel('Month')
plt.ylabel('Precipitation')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.tight_layout()
seaborn.distplot(dataset['maxTemp'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 10))
plt.tight_layout()
seaborn.distplot(dataset['miniTemp'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 10))
plt.tight_layout()
seaborn.distplot(dataset['precipitation'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 10))
plt.tight_layout()
seaborn.distplot(dataset['humidityAt3'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 10))
plt.tight_layout()
seaborn.distplot(dataset['humidityAt12'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15, 10))
plt.tight_layout()
seaborn.distplot(dataset['Month'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
X = dataset[['miniTemp', 'maxTemp', 'humidityAt3','humidityAt12']]
y = dataset['precipitation']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %%
model =LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression(normalize=False)

# %%
print('Intercept is :',model.intercept_)
# Out:
# Intercept is : -9.38613205712397

# %%
print('Coefficient is :' ,model.coef_)
# Out:
# Coefficient is : [ 1.22543404 -0.98473528  0.29282243 -0.04414891]

# %%
y_pred= model.predict(X_test)

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test, predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 7.917194300187993
# MSE: 228.66754492584838
# RMSE: 15.121757335900096
